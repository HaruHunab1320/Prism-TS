# %% [markdown]
# # Lumina Training Log (Mac-first)
#
# This notebook is a running log of experiments, commands, results, and insights.
# Update it after each run so we can track progress.

# %% [markdown]
# ## Status Snapshot
# - Date:
# - Model:
# - Dataset:
# - Key metrics:
# - Next step:

# %% [markdown]
# ## Experiment Log Template
# Use one section per experiment.

# %% [markdown]
# ### Experiment 01 —
# **Goal:**
#
# **Command:**
# ```bash
#
# ```
#
# **Results:**
# - Accuracy:
# - ECE / MSE:
# - OOD AUROC:
#
# **Notes / Insight:**
# -

# %% [markdown]
# ## Current Best Recipe (copy/paste)
# ```bash
# python -m training.train_gpt2_confidence \
#   --data-root datasets_merged \
#   --domain general \
#   --epochs 2 \
#   --batch-size 8 \
#   --freeze-base \
#   --unfreeze-n 4 \
#   --lr 5e-6 \
#   --conf-tau 3.0 \
#   --conf-min 0.05 \
#   --conf-max 0.8 \
#   --overconf-weight 0.2 \
#   --prior-weight 0.05 \
#   --max-train-samples 20000 \
#   --max-val-samples 2000
#
# python -m evaluation.eval_gpt2_confidence \
#   --data-root datasets_merged \
#   --domain general \
#   --max-samples 200 \
#   --weights outputs_gpt2/general_gpt2_confidence.pt \
#   --temperature outputs_gpt2/temperature.json
#
# python evaluation/calibrate_confidence.py \
#   --input outputs_gpt2/calibration_data.json \
#   --output outputs_gpt2/temperature.json
# ```
