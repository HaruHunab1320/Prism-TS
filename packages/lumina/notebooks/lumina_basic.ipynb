# %% [markdown]
# # Lumina Basic (Single-Model) Notebook\n\nThis notebook is for the single-model Lumina architecture (baseline, GPT-2 benchmark track). It assumes the clean-slate workspace lives in `packages/lumina/lumina_basic/`.

# %% [markdown]
# ## 0. Environment

# %%
# Optional: create venv and install deps\n# !python3 -m venv .venv\n# !source .venv/bin/activate\n# !pip install mlx mlx-lm tqdm transformers datasets

# %% [markdown]
# ## 1. Data (v2 generator)

# %%
# !python lumina_basic/data/generate_v2.py

# %% [markdown]
# ## 2. Train Baseline Specialist (single-model track)

# %%
# Example: train prism specialist as single-model baseline\n!python lumina_basic/training/train_v2.py --domain prism --size small --epochs 10

# %% [markdown]
# ## 3. Evaluation

# %%
# Placeholder: add evaluation script here\n!python lumina_basic/run_v2.py --eval-only
