# %% [markdown]
# # Lumina Multi-Model Notebook\n\nThis notebook is for the router + specialists + aggregator architecture. It assumes the clean-slate workspace lives in `packages/lumina/lumina_multimodel/`.

# %% [markdown]
# ## 0. Environment

# %%
# Optional: create venv and install deps\n# !python3 -m venv .venv\n# !source .venv/bin/activate\n# !pip install mlx mlx-lm tqdm transformers datasets

# %% [markdown]
# ## 1. Data

# %%
# Placeholder: add multi-model data generator when ready\n# !python lumina_multimodel/data/generate_data.py

# %% [markdown]
# ## 2. Train Specialists

# %%
# Placeholder: train specialists (prism/math/code/general)\n# !python lumina_multimodel/training/train_specialist.py --domain prism --epochs 10

# %% [markdown]
# ## 3. Train Router

# %%
# Placeholder: router training\n# !python lumina_multimodel/training/train_router.py --epochs 10

# %% [markdown]
# ## 4. Train Aggregator

# %%
# Placeholder: aggregator training\n# !python lumina_multimodel/training/train_aggregator.py --epochs 10

# %% [markdown]
# ## 5. Evaluation

# %%
# Placeholder: end-to-end eval\n# !python lumina_multimodel/evaluation/run_eval.py
